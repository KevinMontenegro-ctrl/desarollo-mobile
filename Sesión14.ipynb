# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinMontenegro-ctrl/desarollo-mobile/blob/main/Sesi%C3%B3n13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
El video de hoy explicaba como el celebro humano procesa la infromacion mediante la codificacion neuronal, funcionando como un sistemas de procesamiento paralelo avanzado el cual inspira el desarrollo de la inteligencia artificial y robotica.
