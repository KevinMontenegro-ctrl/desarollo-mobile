# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinMontenegro-ctrl/desarollo-mobile/blob/main/sesion12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
En el desarrollo móvil, la restricción de hardware obliga a optimizar memoria, batería y CPU, porque los dispositivos no tienen los recursos de una computadora. A esto se suma una red inalámbrica poco potente, con conexiones lentas o intermitentes, lo que exige caché, modo offline, reintentos y sincronización eficiente. Flutter y Dart ayudan con el rendimiento, pero el diseño debe asumir estas limitaciones desde el inicio.

Además, toda aplicación debe respetar el ciclo de vida móvil "5 pasos": creación, inicio o estado activo, pausa, segundo plano y cierre o destrucción. En cada transición se deben liberar o conservar recursos, guardar el estado y cancelar tareas. Ignorarlo provoca fugas de memoria, consumo excesivo de batería o pérdida de datos, especialmente cuando hay streams y conexiones débiles.
