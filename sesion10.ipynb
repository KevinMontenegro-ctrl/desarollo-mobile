# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinMontenegro-ctrl/desarollo-mobile/blob/main/sesion10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
El “95% de los desarrollos móviles están hechos en Kotlin” es una simplificación: en realidad, Google afirma que más del 95% de las 1000 apps Android principales usan Kotlin. Su ascenso se debe a que Google lo adoptó como lenguaje preferido para Android en 2019: es conciso, interoperable con Java, seguro y con corrutinas.

Kotlin busca evitar el “error del billón de dólares” de Tony Hoare: la referencia nula, que provoca fallos y pérdidas enormes. Para ello, su seguridad de nulos distingue entre tipos no nulos (String) y nulables (String?), obligando a manejar el null con ?., ?: o comprobaciones. Así reduce los NullPointerException en tiempo de compilación. En resumen: Kotlin no elimina todos los errores, pero hace que la seguridad frente a nulos sea parte del lenguaje.
