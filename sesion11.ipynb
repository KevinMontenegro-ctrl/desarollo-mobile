# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinMontenegro-ctrl/desarollo-mobile/blob/main/sesion11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Dart es el lenguaje de Flutter, que permite crear aplicaciones multiplataforma para Windows e iOS desde una misma base de código, aunque en iOS se requiere Mac/Xcode y algunos plugins deben adaptarse a cada plataforma. En Flutter, el hot restart o hot reset reinicia la app desde cero muy rápido sin recompilar todo, pero pierde el estado; no debe confundirse con el hot reload, que aplica cambios conservando el estado.

El desarrollo de interfaz guiado en Flutter es declarativo y basado en widgets: describes la UI según el estado y el framework la reconstruye automáticamente. Un broadcast stream en Dart permite múltiples oyentes al mismo tiempo, a diferencia de un stream normal que solo admite uno, y se usa para eventos globales como cambios de sesión, notificaciones o sensores.
