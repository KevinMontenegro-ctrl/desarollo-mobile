# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinMontenegro-ctrl/desarollo-mobile/blob/main/sesion13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
examina el contexto de uso móvil como un sistema de supervivencia interactiva diseñado para personas en movimiento y con atención fragmentada. Explica cómo la imprecisión motora y el bloqueo visual de la propia mano obligan a utilizar controles sobredimensionados e intuitivos. Advierte sobre el peligro de usar Lorem Ipsum en prototipos, señalando que el texto debe funcionar con la claridad de una señalización de emergencia basada en alto contraste y jerarquía visual agresiva. Por último, establece que ante la imposibilidad de mirar la pantalla, la interfaz debe comunicarse mediante tonos de audio, respuestas hápticas y lectura por voz
